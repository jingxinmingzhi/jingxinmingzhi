# %%
import pandas as pd

# %%
df=pd.read_csv("D:/jupyter/ant-learn-pandas-master/datas/beijing_tianqi/beijing_tianqi_2018.csv")

# %%
df
# Out:
#             ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0    2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1    2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2    2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3    2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4    2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1
# ..          ...    ...    ...    ...       ...    ...  ...     ...       ...
# 360  2018-12-27    -5℃   -12℃   多云~晴       西北风     3级   48       优         1
# 361  2018-12-28    -3℃   -11℃      晴       西北风     3级   40       优         1
# 362  2018-12-29    -3℃   -12℃      晴       西北风     2级   29       优         1
# 363  2018-12-30    -2℃   -11℃   晴~多云       东北风     1级   31       优         1
# 364  2018-12-31    -2℃   -10℃     多云       东北风     1级   56       良         2
#
# [365 rows x 9 columns]

# %%
df.loc[0,'ymd']
# Out:
# '2018-01-01'

# %%
df.set_index('ymd')
# Out:
#            bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1
# ...           ...    ...    ...       ...    ...  ...     ...       ...
# 2018-12-27    -5℃   -12℃   多云~晴       西北风     3级   48       优         1
# 2018-12-28    -3℃   -11℃      晴       西北风     3级   40       优         1
# 2018-12-29    -3℃   -12℃      晴       西北风     2级   29       优         1
# 2018-12-30    -2℃   -11℃   晴~多云       东北风     1级   31       优         1
# 2018-12-31    -2℃   -10℃     多云       东北风     1级   56       良         2
#
# [365 rows x 8 columns]

# %%
df.loc[1:5,:]
# Out:
#           ymd  bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 1  2018-01-02       2    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03       2    -5℃     多云        北风   1-2级   28       优         1
# 3  2018-01-04       0    -8℃      阴       东北风   1-2级   28       优         1
# 4  2018-01-05       3    -6℃   多云~晴       西北风   1-2级   50       优         1
# 5  2018-01-06       2    -5℃   多云~阴       西南风   1-2级   32       优         1

# %%
df['bWendu']=df['bWendu'].str.replace("℃","").astype('int32')

# %%
df.loc[:,"yWendu"]=df.loc[:,'yWendu'].str.replace("℃","").astype("int32")

# %%
df.loc[(df['bWendu']>2)&(df['yWendu']<-5),:]
# Out:
#             ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0    2018-01-01       3      -6   晴~多云       东北风   1-2级   59       良         2
# 4    2018-01-05       3      -6   多云~晴       西北风   1-2级   50       优         1
# 12   2018-01-13       3      -7     多云        南风   1-2级  126    轻度污染         3
# 16   2018-01-17       6      -7   多云~晴       西北风   1-2级   82       良         2
# 17   2018-01-18       5      -6      晴       西南风   1-2级   80       良         2
# 19   2018-01-20       3      -6   晴~多云        东风   1-2级   64       良         2
# 29   2018-01-30       4      -7      晴       西北风   1-2级   36       优         1
# 30   2018-01-31       3      -8      晴       西南风   1-2级   60       良         2
# 31   2018-02-01       4      -7     多云        北风   1-2级   68       良         2
# 36   2018-02-06       3      -7   多云~阴       西南风   1-2级   56       良         2
# 38   2018-02-08       3      -7     多云        南风   3-4级   67       良         2
# ...

# %%
df
# Out:
#             ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0    2018-01-01       3      -6   晴~多云       东北风   1-2级   59       良         2
# 1    2018-01-02       2      -5   阴~多云       东北风   1-2级   49       优         1
# 2    2018-01-03       2      -5     多云        北风   1-2级   28       优         1
# 3    2018-01-04       0      -8      阴       东北风   1-2级   28       优         1
# 4    2018-01-05       3      -6   多云~晴       西北风   1-2级   50       优         1
# ..          ...     ...     ...    ...       ...    ...  ...     ...       ...
# 360  2018-12-27      -5     -12   多云~晴       西北风     3级   48       优         1
# 361  2018-12-28      -3     -11      晴       西北风     3级   40       优         1
# 362  2018-12-29      -3     -12      晴       西北风     2级   29       优         1
# 363  2018-12-30      -2     -11   晴~多云       东北风     1级   31       优         1
# 364  2018-12-31      -2     -10     多云       东北风     1级   56       良         2
#
# [365 rows x 9 columns]

# %%
type(df.loc[1,'bWendu'])
# Out:
# numpy.int32
